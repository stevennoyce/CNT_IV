# %%
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../')

from utilities import DataLoggerUtility as dlu
from utilities import DataPlotterUtility as dpu
from control_scripts import Device_History as DH
import launcher
import defaults

from matplotlib import pyplot as plt
import numpy as np

saveFolder = '../../../Publications/2018-04-30 Bias Stress ACS/Plots'

# %config InlineBackend.figure_format = 'svg'


#def makePlots(waferID, chipID, deviceID, startExperimentNumber=0, endExperimentNumber=float('inf'), 
#              specificPlot='', figureSize=None, saveFolder=None, saveNamePrefix = '', save=False, 
#              startRelativeIndex=0, endRelativeIndex=float('inf')):
#    parameters = defaults.get()
#    
#    dpu.publication_mode = True
#    
#    parameters['runType'] = 'DeviceHistory'
#    parameters['waferID'] = waferID
#    parameters['chipID'] = chipID
#    parameters['deviceID'] = deviceID
#    parameters['DeviceHistory']['excludeDataBeforeJSONExperimentNumber'] = startExperimentNumber
#    parameters['DeviceHistory']['excludeDataAfterJSONExperimentNumber'] = endExperimentNumber
#    parameters['DeviceHistory']['excludeDataBeforeJSONRelativeIndex'] = startRelativeIndex
#    parameters['DeviceHistory']['excludeDataAfterJSONRelativeIndex'] = endRelativeIndex
#    parameters['DeviceHistory']['postFiguresGenerated'] = False
#    parameters['DeviceHistory']['saveFiguresGenerated'] = save
#    parameters['DeviceHistory']['gateSweepDirection'] = 'reverse'
#    parameters['DeviceHistory']['plotInRealTime'] = True
#    parameters['DeviceHistory']['specificPlotToCreate'] = specificPlot
#    parameters['DeviceHistory']['figureSizeOverride'] = figureSize
#    if saveFolder is not None:
#        parameters['plotsFolder'] = saveFolder + '/'
#    
#    parameters['plotsFolder'] += saveNamePrefix
#    
#    launcher.run(parameters)

# %%
print('# Figure 2a')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 3, 3, 'FullSubthresholdCurveHistory', (2.2,2.2), saveFolder, 'Figure 2a - ', False, mode_parameters={'publication_mode':True}) # Static Bias
# Out:
# # Figure 2a
# [(<Figure size 158.4x158.4 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x10876e5c0>)]

# %%
print('# Figure 2b')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 4, 4, 'FullStaticBiasHistory', (3.3,2.2), saveFolder, 'Figure 2b - ', True, mode_parameters={'publication_mode':True}) # Static Bias
# Out:
# # Figure 2b
# [(<Figure size 237.6x158.4 with 1 Axes>,
#   (<matplotlib.axes._subplots.AxesSubplot at 0x1223de780>, None, None))]

# %%
print('# Figure 3a')
makePlots('C127', 'E', '15-16', 2, 10, 'FullStaticBiasHistory', (2,1.6), saveFolder, 'Figure 3a - ', True) # On/Off Current
# Out:
# # Figure 3a

# %%
print('# Figure 3a')
dpu.plotOffCurrent = False
makePlots('C127', 'E', '15-16', 3, 10, 'OnAndOffCurrentHistory', (2,1.6), saveFolder, 'Figure 3a - ', True) # On/Off Current
dpu.plotOffCurrent = True
# Out:
# # Figure 3a
# No Arduino connected.
# Sensor data: {}

# %%
print('# Figure 3a')

staticBiass = dlu.loadJSON('data/C127/E/15-16/', 'StaticBias.json')
staticBiass = dlu.filterHistoryGreaterThan(staticBiass, 'experimentNumber', 6)
staticBiass = dlu.filterHistoryLessThan(staticBiass, 'experimentNumber', 10)

gateSweeps = dlu.loadJSON('data/C127/E/15-16/', 'GateSweep.json')
gateSweeps = dlu.filterHistoryGreaterThan(gateSweeps, 'experimentNumber', 6)
gateSweeps = dlu.filterHistoryLessThan(gateSweeps, 'experimentNumber', 10)

initialTime = staticBiass[0]['Results']['timestamps'][0]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(2.22,1.6), sharex=True, gridspec_kw={'width_ratios':[1], 'height_ratios':[3,1]})
# fig = plt.figure(figsize=(2,1.6))
onCurrents = []
times = []
timeStampss = []
VDSs = []

for gateSweep, staticBias in zip(gateSweeps, staticBiass):
    timestamps = np.array(staticBias['Results']['timestamps'])/3600/24
    times.append(timestamps[0])
    timeStampss.append(timestamps - times[0])
    VDSs.append(staticBias['StaticBias']['drainVoltageSetPoint'])
#     Id = np.array(staticBias['Results']['id_data'])
    onCurrents.append(gateSweep['Results']['onCurrent'])
    ax2.set_prop_cycle(None)
#     ax2.plot([])
    ax2.plot((timestamps - times[0]), np.ones(len(timestamps))*staticBias['StaticBias']['drainVoltageSetPoint'])


colors = dpu.colorsFromMap('hot', 0.7, 0, len(times))['colors']

times = np.array(times)
times = times - times[0]
onCurrents = np.array(onCurrents)
ax1.scatter(times, abs(onCurrents)*1e6, s=2, c=colors)

plt.yticks([1.5,1.8])

# [tick.set_verticalalignment('baseline') for tick in ax1.yaxis.get_majorticklabels()]
ax1.yaxis.get_majorticklabels()[0].set_verticalalignment('baseline')
legend_title = '$V_{{GS}}^{{Hold}}$ = {} V'.format(staticBiass[0]['StaticBias']['gateVoltageSetPoint'])
legend_title += '\n$t_{{Hold}}$ = {} hr'.format(int(staticBiass[0]['StaticBias']['totalBiasTime']//3600))
ax1.legend(title=legend_title, labelspacing=0)
ax1.set_ylim(ymin=0)
ax2.set_xlabel('Time [Days]')
ax2.set_ylabel('$V_{{DS}}^{{Hold}}$ [V]')
ax1.set_ylabel('$I_D$ [$\mu$A]')
plt.tight_layout()
fig.subplots_adjust(hspace=0.03)
fig.align_labels()
plt.savefig(saveFolder + '/Figure 3a - Custom OnCurrent.png', transparent=True, dpi=300)
plt.show()
# Out:
# # Figure 3a
# No handles with labels found to put in legend.

# %%
print('# Figure 3b')
DH.makePlots(defaults.get(),'C127', 'E', '15-16', 6, 10, 'FullTransferCurveHistory', (1.4,1.7), saveFolder, 'Figure 3b - ', True, mode_parameters={'publication_mode':True,'errorBarsOn':False}) # Transfer Curve
# Out:
# # Figure 3b
# Error: Unable to find Gate Sweep history.
# []

# %%
print('# Figure 3c')
DH.makePlots(defaults.get(), 'C127', 'P', '1-2', 8, 8, 'FullStaticBiasHistory', (2.22,1.65), saveFolder, 'Figure 3c - ', True, mode_parameters={'publication_mode':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 3c
# Error: Unable to find Static Bias history.
# []

# %%
print('# Figure 3d')
DH.makePlots(defaults.get(), 'C127', 'P', '1-2', 8, 8, 'FullTransferCurveHistory', (1.48,1.74), saveFolder, 'Figure 3d - ', True, mode_parameters={'publication_mode':True,'errorBarsOn':False}) # Transfer Curve
# Out:
# # Figure 3d
# Error: Unable to find Gate Sweep history.

# %%
print('# Figure 4a')
DH.makePlots(defaults.get(), 'C127', 'E', '15-16', 6, 6, 'FullStaticBiasHistory', (5.8,1.408), saveFolder, 'Figure 4a - ', True, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True}) # Static Bias
# Out:
# # Figure 4a
# Error: Unable to find Static Bias history.
# []

# %%
print('# Figure 4a 6 hour')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 104, 104, 'FullStaticBiasHistory', (2.2,1.408), saveFolder, 'Figure 4a - ', True, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4a 6 hour
# Error: Unable to find Static Bias history.
# []

# %%
print('# Figure S1 Grounded Between')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 118, 118, 'FullStaticBiasHistory', (2*2.2,2*1.408), saveFolder, 'Figure S1 Grounded Between - ', True, startRelativeIndex=9, endRelativeIndex=16, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S1 Grounded Between
# Error: Unable to find Static Bias history.
# []

# %%
print('# Figure S2 Floating Between for 30 s')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 119, 119, 'FullStaticBiasHistory', (2*2.2,2*1.408), saveFolder, 'Figure S2 Floating Between 30s - ', True, startRelativeIndex=9, endRelativeIndex=16, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S1 Floating Between for 30 s

# %%
print('# Figure S3 Floating Between for 10 s')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 120, 120, 'FullStaticBiasHistory', (2*2.2,2*1.408), saveFolder, 'Figure S3 Floating Between 10s - ', True, startRelativeIndex=2, endRelativeIndex=9, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S1 Floating Between for 10 s

# %%
print('# Figure S4 Floating Between for 1 s')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 121, 121, 'FullStaticBiasHistory', (2*2.2,2*1.408), saveFolder, 'Figure S4 Floating Between 1s - ', False, startRelativeIndex=2, endRelativeIndex=9, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S4 Floating Between for 1 s

# %%
print('# Figure S5 Floating Between for 0 s')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 122, 122, 'FullStaticBiasHistory', (2*2.2,2*1.408), saveFolder, 'Figure S5 Floating Between 0s - ', False, startRelativeIndex=2, endRelativeIndex=9, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S5 Floating Between for 0 s

# %%
print('# Figure 4a 3 hour')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 100, 100, 'FullStaticBiasHistory', (5.8,1.408), saveFolder, 'Figure 4a - ', False, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4a 3 hour

# %%
print('# Figure 4a 1 hour')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 96, 96, 'FullStaticBiasHistory', (5.8,1.408), saveFolder, 'Figure 4a - ', False, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4a 1 hour

# %%
print('# Figure 4a 30 minute')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 94, 94, 'FullStaticBiasHistory', (5.8,1.408), saveFolder, 'Figure 4a - ', False, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4a 30 minute

# %%
print('# Figure 4a 10 minute')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 92, 92, 'FullStaticBiasHistory', (5.8,1.408), saveFolder, 'Figure 4a - ', False, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4a 10 minute

# %%
print('# Figure 4c 5 minute')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 91, 91, 'FullStaticBiasHistory', (2.27,1.408), saveFolder, 'Figure 4c - ', True, startRelativeIndex=9, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4c 5 minute

# %%
print('# Figure 4a 1 minute')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 89, 89, 'FullStaticBiasHistory', (5.8,1.408), saveFolder, 'Figure 4a - ', False, mode_parameters={'publication_mode':True,'autoStaticBiasSegmentDividers':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 4a 1 minute

# %%
print('# Figure 4b')
DH.makePlots(defaults.get(), 'C127', 'E', '15-16', 6, 6, 'FullStaticBiasHistory', (1.2,1.3), saveFolder, 'Figure 4b - ', True, endRelativeIndex=1, mode_parameters={'publication_mode':True}) # Static Bias
# Out:
# # Figure 4b

# %%
print('# Figure 4c')
DH.makePlots(defaults.get(), 'C127', 'E', '15-16', 6, 6, 'FullSubthresholdCurveHistory', (1.2,1.5), saveFolder, 'Figure 4c - ', True, endRelativeIndex=1, mode_parameters={'publication_mode':True, 'errorBarsOn':False}) # Subthreshold Curve
# Out:
# # Figure 4c

# %%
print('# Figure 4d')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 104, 104, 'FullSubthresholdCurveHistory', (1.45,1.55), saveFolder, 'Figure 4d - ', True, mode_parameters={'publication_mode':True, 'errorBarsOn':False}) # Subthreshold Curve
# Out:
# # Figure 4d

# %%
print('# Figure 4e')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 91, 91, 'FullTransferCurveHistory', (1.45,1.5), saveFolder, 'Figure 4e - ', True, startRelativeIndex=9, mode_parameters={'publication_mode':True, 'errorBarsOn':False}) # Subthreshold Curve
# Out:
# # Figure 4e

# %%
print('# Figure 5a')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 24, 24, 'FullStaticBiasHistory', (3.4,2.6), saveFolder, 'Figure 5a - ', True, mode_parameters={'publication_mode':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure 5a

# %%
print('# Figure S4')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 112, 112, 'FullStaticBiasHistory', (3.4,2.6), saveFolder, 'Figure S4 - ', True, mode_parameters={'publication_mode':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S4

# %%
print('# Figure S4b')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 114, 114, 'FullStaticBiasHistory', (3.4,2.6), saveFolder, 'Figure S4b - ', True, mode_parameters={'publication_mode':True, 'plotGradient':True}) # Static Bias
# Out:
# # Figure S4b

# %%
print('# Figure S4c')
DH.makePlots(defaults.get(), 'C127', 'X', '15-16', 114, 114, 'FullSubthresholdCurveHistory', (3.4,2.6), saveFolder, 'Figure S4c - ', True, mode_parameters={'publication_mode':True}) # Static Bias
# Out:
# # Figure S4c

# %%
parametersSets = dlu.loadJSON('data/C127/X/15-16/', 'StaticBias.json')
parametersSets = dlu.filterHistoryGreaterThan(parametersSets, 'experimentNumber', 24)
parametersSets = dlu.filterHistoryLessThan(parametersSets, 'experimentNumber', 24)

initialTime = parametersSets[0]['Results']['timestamps'][0]

fig = plt.figure(figsize=(1.8,1.8))

for parameters in parametersSets:
    timestamps = np.array(parameters['Results']['timestamps'])
    timestamps = timestamps - timestamps[0]
    timestamps = timestamps/3600
    Id = np.array(parameters['Results']['id_data'])
    
    colors = dpu.colorsFromMap('plasma', 0, 0.85, len(Id))['colors']
    alphas = np.linspace(0,1,len(Id))
    
    N = 10
    plt.semilogy(timestamps, abs(Id))
#     for i in range(0, len(Id)-1, N):
#         plt.gca().set_prop_cycle(None)
#         plt.semilogy(timestamps[i:i+1+N], abs(Id[i:i+1+N]), c=colors[i])
#         plt.semilogy(timestamps[i:i+1+N], abs(Id[i:i+1+N]), alpha=alphas[i])

plt.xlabel('Time After Sweep [hr]')
plt.ylabel('$I_D$ [A]')
plt.tight_layout()
# plt.savefig(saveFolder + '/Figure ? - Dynamic Range Change.png', transparent=True, dpi=300)
plt.show()

# %%
from scipy.optimize import curve_fit

def trapFill1(t, v, A, tau):
    return v + A*np.exp(-t/tau)

popts = []

for parameters in parametersSets:
    timestamps = np.array(parameters['Results']['timestamps'])
    timestamps = timestamps - timestamps[0]
    timestamps = timestamps/3600
    Id = np.array(parameters['Results']['id_data'])
    
    popt, pcov = curve_fit(trapFill1, timestamps, abs(Id))
    
    popts.append(popt)
    
    timestamps2 = np.linspace(0,2,100)
    plt.plot(timestamps2, trapFill1(timestamps2, *popt))
    plt.plot(timestamps, abs(Id))

plt.show()

taus = [popt[2] for popt in popts]
plt.semilogy(taus)
plt.ylabel('Tau [hours]')
plt.show()

print(np.median(taus))
# Out:
# 0.244146722649

# %%
from scipy.optimize import curve_fit

def trapFill2(t, v, A):
    tau = 0.244146722649
    tau = 0.5
    return v + A*np.exp(-t/tau)

for parameters in parametersSets:
    timestamps = np.array(parameters['Results']['timestamps'])
    timestamps = timestamps - timestamps[0]
    timestamps = timestamps/3600
    Id = np.array(parameters['Results']['id_data'])
    
    popt, pcov = curve_fit(trapFill2, timestamps, abs(Id))
    
    timestamps2 = np.linspace(0,2,100)
    plt.plot(timestamps2, trapFill2(timestamps2, *popt))
    plt.plot(timestamps, abs(Id))

plt.show()

# %%
IdsInitial = []
IdsFinal = []
Vgss = []

for parameters in parametersSets:
    Id = np.array(parameters['Results']['id_data'])
    Vgs = np.array(parameters['Results']['vgs_data'])
    IdsInitial.append(np.mean(Id[0:2]))
    IdsFinal.append(np.mean(Id[-60:-1]))
    Vgss.append(Vgs[0])

fig = plt.figure(figsize=(1.7,1.89))
colors = dpu.colorsFromMap('plasma', 0, 0.75, 2)['colors']
plt.semilogy(Vgss, np.abs(IdsInitial), label='Initial\n   DR = {:.0f}\n'.format(IdsInitial[-1]/IdsInitial[0]), c=colors[0])
plt.semilogy(Vgss, np.abs(IdsFinal), label='Terminal\n   DR = {:.0f}'.format(IdsFinal[-1]/IdsFinal[0]), c=colors[1])
plt.legend()
plt.xlabel('$V_{GS}^{{Hold}}$')
plt.ylabel('$I_D$ [A]')
plt.tight_layout()
plt.savefig(saveFolder + '/Figure 5c - Initial and Terminal Responses.png', transparent=True, dpi=300)
plt.show()

# %%
print('# Figure 2b')
# makePlots('C127', 'X', '15-16', 4, 4, 'FullStaticBiasHistory', (3.3,2.2), saveFolder, 'Figure 2 - ', True) # Static Bias

parametersSets1 = dlu.loadJSON('data/C127/X/15-16/', 'StaticBias.json')
parametersSets1 = dlu.filterHistoryGreaterThan(parametersSets1, 'experimentNumber', 4)
parametersSets1 = dlu.filterHistoryLessThan(parametersSets1, 'experimentNumber', 4)

initialTime = parametersSets1[0]['Results']['timestamps'][0]
timestamps1 = np.array([])
Ids1 = np.array([])

fig = plt.figure(figsize=(3.1,2.22))

for parameters in parametersSets1:
    timestamps = np.array(parameters['Results']['timestamps'])
    timestamps1 = np.append(timestamps1, (timestamps - initialTime)/3600/24)
    Ids1 = np.append(Ids1, np.array(parameters['Results']['id_data']))

parametersSets2 = dlu.loadJSON('data/C127/X/15-16/', 'StaticBias.json')
parametersSets2 = dlu.filterHistoryGreaterThan(parametersSets2, 'experimentNumber', 7)
parametersSets2 = dlu.filterHistoryLessThan(parametersSets2, 'experimentNumber', 7)

initialTime = parametersSets2[0]['Results']['timestamps'][0]
timestamps2 = np.array([])
Ids2 = np.array([])

for parameters in parametersSets2:
    timestamps = np.array(parameters['Results']['timestamps'])
    timestamps2 = np.append(timestamps2, (timestamps - initialTime)/3600/20.3)
    Ids2 = np.append(Ids2, np.array(parameters['Results']['id_data']))

def rollingMean(x, N):
    return np.convolve(x, np.ones((N,))/N, mode='valid')

plt.plot(timestamps2, abs(Ids2)/1e-6, label='$V_{{DS}}^{{Hold}}$ = 0.5 V')
plt.plot(timestamps1, abs(Ids1)/1e-6, label='$V_{{DS}}^{{Hold}}$ = 0.1 V')
plt.xlabel('Time [days]')
plt.ylabel('$-I_D$ [$\mu$A]')
leg = plt.legend(title='$V_{{GS}}^{{Hold}}$ = -15 V', labelspacing=0)
leg._legend_box.align = "right"
plt.ylim(ymin=0)
plt.tight_layout()
plt.savefig(saveFolder + '/Figure 2b - Long Term.png', transparent=True, dpi=300)
plt.show()
# Out:
# # Figure 2b

# %%
fig = plt.figure(figsize=(2.2,2.2))

startIndex1 = np.argmax(timestamps1>6)
stopIndex1 = np.argmax(timestamps1>6.02)

startIndex2 = np.argmax(timestamps2>6)
stopIndex2 = np.argmax(timestamps2>6.02)

ax1 = plt.subplot(211)
plt.plot(timestamps2[startIndex2:stopIndex2], abs(Ids2[startIndex2:stopIndex2])/1e-6, '.')
plt.setp(ax1.get_xticklabels(), visible=False)
plt.ylabel('$-I_D$ [$\mu$A]')

ax2 = plt.subplot(212, sharex=ax1)
plt.plot([])
plt.plot(timestamps1[startIndex1:stopIndex1], abs(Ids1[startIndex1:stopIndex1])/1e-6, '.')

plt.xlabel('Time [days]')
plt.ylabel('$-I_D$ [$\mu$A]')

fig.align_labels()
plt.tight_layout()
fig.subplots_adjust(hspace=0.05)
plt.savefig(saveFolder + '/Figure 2c - Magnified Fragment.png', transparent=True, dpi=300)
plt.show()

# %%
print('# Figure 2a')
# makePlots('C127', 'X', '15-16', 3, 3, 'FullSubthresholdCurveHistory', (2.2,2.2), saveFolder, 'Figure 2a - ', False) # Static Bias

parametersSets = dlu.loadJSON('data/C127/X/15-16/', 'GateSweep.json')
parametersSets = dlu.filterHistoryGreaterThan(parametersSets, 'experimentNumber', 3)
parametersSets = dlu.filterHistoryLessThan(parametersSets, 'experimentNumber', 3)

Idss = np.array([])
Vgss = np.array([])

for parameters in parametersSets:
    Idss = np.append(Idss, np.array(parameters['Results']['id_data'][1]))
    Vgss = np.append(Vgss, np.array(parameters['Results']['vgs_data'][1]))

fig = plt.figure(figsize=(2.2,2.25))
plt.plot([])
plt.plot([])
plt.plot([])
plt.plot([])
p1 = plt.plot(Vgss, abs(Idss)/1e-6, ':')
p1[0].set_dash_capstyle('round')
plt.gca().spines['left'].set_alpha(0)
plt.gca().tick_params(axis='y', color=p1[-1].get_color())
plt.xlabel('$V_{{GS}}^{{Sweep}}$ [V]')
plt.ylabel('$-I_{{D}}$ [$\mu$A]')
plt.twinx()
plt.plot([])
plt.plot([])
plt.plot([])
p2 = plt.semilogy(Vgss, abs(Idss))
plt.gca().spines['right'].set_linewidth(p2[-1].get_linewidth()*0.8)
plt.gca().spines['right'].set_capstyle('round')
plt.gca().spines['right'].set_color(p2[-1].get_color())
plt.gca().spines['left'].set_color(p1[-1].get_color())
plt.gca().spines['left'].set_linestyle(p1[-1].get_linestyle())
plt.gca().spines['left'].set_linewidth(p1[-1].get_linewidth()*0.8)
plt.gca().spines['left'].set_capstyle('round')
plt.gca().tick_params(axis='y', which='both', color=p2[-1].get_color())
plt.ylabel('$-I_{{D}}$ [A]', rotation=-90, va='bottom')
plt.legend(title='$V_{{DS}}^{{Sweep}}$ = {} V'.format(parametersSets[0]['GateSweep']['drainVoltageSetPoint']), labelspacing=0)
plt.ylim(ymin=1e-8)
plt.tight_layout()
# plt.gca().yaxis.label.set_rotation()
plt.savefig(saveFolder + '/Figure 2a - Initial Sweep.png', transparent=True, dpi=300)
plt.show()
# Out:
# # Figure 2a
# No handles with labels found to put in legend.

# %%
print('# Figure 5a')
# makePlots('C127', 'X', '15-16', 24, 24, 'FullStaticBiasHistory', (3.4,2.6), saveFolder, 'Figure 5a - ', True) # Static Bias

parametersSets = dlu.loadJSON('data/C127/X/15-16/', 'StaticBias.json')
parametersSets = dlu.filterHistoryGreaterThan(parametersSets, 'experimentNumber', 24)
parametersSets = dlu.filterHistoryLessThan(parametersSets, 'experimentNumber', 24)

initialTime = parametersSets[0]['Results']['timestamps'][0]

fig = plt.figure(figsize=(3.4,2.6))

for parameters in parametersSets:
    timestamps = np.array(parameters['Results']['timestamps'])
    timestamps = timestamps/3600
    Id = np.array(parameters['Results']['id_data'])
    
    colors = dpu.colorsFromMap('plasma', 0, 0.95, len(Id))['colors']
    
    N = 40
    
    for i in range(0, len(Id)-1, N):
        plt.gca().set_prop_cycle(None)
        plt.plot(timestamps[i:i+1+N], abs(Id[i:i+1+N]), color=colors[i])
#         plt.semilogy(timestamps[i:i+1+N], abs(Id[i:i+1+N]), alpha=alphas[i])

plt.xlabel('Time After Gate Sweep [hr]')
plt.ylabel('$I_D$')
plt.tight_layout()
# plt.savefig(saveFolder + '/Figure 5a - Drift to Common.png', transparent=True, dpi=300)
plt.show()
# Out:
# # Figure 5a
